# %%
eigs1 = [-0.000294541882,-0.000258792366,-0.000184888195,-0.000154898284,-7.25359641e-05,-6.08570481e-05,-5.15777647e-05,-2.48038195e-05,-1.87634505e-05,-1.41997007e-05,-5.95506526e-06,-5.81465065e-06,-5.78586605e-06,-5.68890209e-06,-5.57168096e-06,-5.52251367e-06, -5.4428242e-06,-5.40346446e-06,-5.39295161e-06,-5.32541799e-06,-5.25466749e-06,-5.18758679e-06,-5.17831995e-06,-5.16165665e-06,-5.04979835e-06,-5.04377931e-06,-5.02176545e-06,-5.00864826e-06,-4.97872134e-06,-4.95584618e-06,-4.88509295e-06,-4.85785722e-06,-4.82658925e-06,-4.81654433e-06,-4.80680092e-06,-4.76022251e-06,-4.72958391e-06,-4.66502206e-06,-4.66430811e-06,-4.64578761e-06,-4.64477944e-06,-4.59181501e-06,-4.56527823e-06,-4.52511176e-06,-4.49388426e-06,-4.49114395e-06,-4.46847298e-06,-4.46787544e-06,-4.45196565e-06,-4.42290093e-06,-4.39569249e-06,-4.38942607e-06,-4.36707796e-06,-4.35893662e-06,-4.34096319e-06,-4.30731461e-06,-4.28194198e-06,-4.27739178e-06,-4.25595954e-06,-4.25467488e-06,-4.25021017e-06,-4.23534584e-06,-4.21128289e-06,-4.19749631e-06,-4.19060189e-06, -4.1641797e-06,-4.13368298e-06,-4.11010842e-06,-4.09608356e-06,-4.08139249e-06,-4.05991204e-06,-4.05703804e-06,-4.02967635e-06,-4.02080059e-06,-4.00804629e-06,-3.97790154e-06,-3.97452823e-06,-3.97120766e-06,-3.96770247e-06,-3.95689494e-06,-3.94273684e-06,-3.92248648e-06,-3.90709556e-06,-3.89339266e-06,-3.86699185e-06, -3.8486196e-06, -3.8405019e-06,-3.81960308e-06,-3.80544498e-06,-3.79219387e-06,-3.76875778e-06,-3.75061722e-06,-3.73944522e-06,-3.73276225e-06,-3.71587021e-06,-3.70172938e-06,-3.69754207e-06,-3.68473275e-06,-3.67636153e-06,-3.66391851e-06,-3.65450569e-06,-3.64498192e-06,-3.64269476e-06,-3.61964067e-06,-3.60611466e-06,-3.60517674e-06,-3.59413866e-06,-3.58516263e-06,-3.55160682e-06,-3.53282485e-06,-3.51430253e-06, -3.5069711e-06,-3.50041273e-06,-3.48368008e-06,-3.46545903e-06,-3.46415663e-06,-3.45273747e-06,-3.43485044e-06,-3.42907902e-06,-3.41044893e-06,-3.39628696e-06, -3.3883332e-06,-3.38243831e-06,-3.36922403e-06,-3.35239974e-06,-3.34165293e-06,-3.32343188e-06,-3.31037472e-06,-3.30041712e-06,-3.29532259e-06,-3.28976103e-06,-3.27816792e-06,-3.26742997e-06,-3.26377949e-06,-3.25216524e-06,-3.24515031e-06,-3.23301401e-06,-3.20285426e-06,-3.18769435e-06,-3.18105322e-06,-3.16955084e-06, -3.1600498e-06,-3.14579211e-06,  -3.138181e-06,-3.13135433e-06,-3.10641099e-06, -3.0954966e-06,-3.08148719e-06,-3.07994901e-06,-3.06400511e-06,-3.05112098e-06,-3.04099922e-06,-3.03789784e-06,-3.03291677e-06,-3.02216313e-06,-3.01977889e-06,-3.00225338e-06,-2.99356452e-06,-2.98695386e-06, -2.9572941e-06,-2.95689847e-06,-2.94806205e-06,-2.93956714e-06,-2.92387358e-06,-2.91438323e-06,-2.90760909e-06, -2.9013745e-06,-2.88598244e-06,-2.87616967e-06,-2.85981241e-06,-2.84856628e-06,-2.84571797e-06,-2.84277962e-06,-2.82625956e-06,-2.81899383e-06,-2.81396433e-06, -2.8107745e-06,-2.79831602e-06,-2.78498283e-06,-2.77104277e-06,-2.75798175e-06,-2.75465322e-06,-2.74214153e-06,-2.73451246e-06,-2.72933221e-06,-2.71648128e-06,-2.70786541e-06,-2.69763041e-06, -2.6876769e-06,-2.68136978e-06,-2.66906477e-06,-2.66403845e-06,-2.65225276e-06,-2.65069798e-06,-2.63388597e-06,-2.62790081e-06, -2.6186417e-06,-2.60539082e-06,-2.58801742e-06,-2.57728448e-06,-2.56799331e-06,-2.55953751e-06,-2.55538316e-06,-2.55135183e-06,-2.54117731e-06,-2.53750432e-06,-2.52859491e-06,-2.52210543e-06,-2.50837115e-06,-2.50096377e-06,-2.48423112e-06,-2.46258605e-06,-2.45840261e-06,-2.44785497e-06,-2.43209297e-06,-2.42407486e-06,-2.42071178e-06,-2.41677026e-06,-2.40856752e-06,-2.40831332e-06,-2.38651592e-06,-2.38068151e-06,-2.37870699e-06,-2.36482651e-06,-2.35490688e-06,-2.35151447e-06,-2.34917889e-06,-2.33936453e-06,-2.33115156e-06, -2.3294906e-06,-2.31230524e-06,-2.29745046e-06,-2.29616967e-06,-2.28870431e-06,-2.28236786e-06, -2.2766535e-06,-2.26838256e-06,-2.25674921e-06,-2.24185806e-06,-2.24061614e-06,-2.22802737e-06,-2.21776327e-06,-2.21559958e-06,-2.20787933e-06,-2.20456218e-06,-2.19601179e-06,-2.18088712e-06,-2.16663193e-06,-2.15676027e-06,-2.15422187e-06,-2.14339389e-06,-2.13803014e-06,-2.12929467e-06,-2.11959241e-06,-2.10608391e-06,-2.10113558e-06,-2.09615678e-06,-2.08861115e-06,-2.08339384e-06,-2.07976564e-06,-2.06579853e-06, -2.0610405e-06,-2.05012634e-06,-2.03948161e-06,-2.03226682e-06, -2.0274399e-06,-2.01600164e-06,-2.01452212e-06,-2.01036619e-06,-1.99217766e-06,-1.98787779e-06,-1.98494263e-06,-1.97520285e-06,-1.96814017e-06,-1.96460314e-06,-1.95123948e-06,-1.94889026e-06,-1.93751316e-06,-1.92944594e-06,-1.91584695e-06,-1.91547315e-06,-1.90503101e-06,-1.90012963e-06,-1.87813362e-06,-1.87554599e-06,-1.86595025e-06,-1.86201032e-06,  -1.851609e-06,-1.84479927e-06,-1.83931002e-06,-1.82977874e-06,-1.81180485e-06,-1.80933932e-06,-1.80709048e-06,-1.78664243e-06,-1.77732181e-06,-1.77073821e-06,-1.76518574e-06,-1.75718446e-06,-1.75019943e-06,-1.73785031e-06,-1.72625982e-06,-1.71928787e-06,-1.70739838e-06,-1.70556075e-06,-1.69293207e-06,-1.69095028e-06, -1.6869559e-06,-1.68168549e-06,-1.67723897e-06,-1.66090092e-06,-1.65573738e-06,-1.65003735e-06,-1.63697428e-06,  -1.626227e-06,-1.61581147e-06,-1.60750346e-06,-1.60456102e-06,-1.60035074e-06,-1.59225374e-06,-1.58211242e-06,-1.57999625e-06,-1.57177215e-06,-1.55804253e-06,-1.55327325e-06,-1.54400368e-06,-1.53445626e-06,-1.53266819e-06,-1.52635562e-06,-1.51714448e-06,-1.50804476e-06,-1.50551455e-06,-1.49849507e-06,-1.49701532e-06, -1.4875535e-06, -1.4797572e-06,-1.47230935e-06,-1.46287289e-06,-1.45922809e-06,-1.45261185e-06,-1.44212015e-06,-1.43540319e-06,-1.43132388e-06,-1.41736905e-06,-1.41279247e-06,-1.40463021e-06,-1.39911663e-06,-1.38875612e-06, -1.3797395e-06, -1.3744293e-06,-1.36511824e-06,-1.35645678e-06,-1.35514506e-06,-1.34730408e-06,-1.34016545e-06,-1.32902221e-06,-1.32043442e-06,-1.31541231e-06,-1.30720241e-06,  -1.301201e-06,-1.29603052e-06,-1.28553904e-06,-1.28125271e-06,-1.26865257e-06,-1.26528994e-06,-1.25882661e-06,-1.24952726e-06,-1.24212988e-06,-1.23344796e-06,-1.22612778e-06,-1.22161225e-06,-1.21678158e-06,-1.20258983e-06,-1.19467745e-06,-1.18832008e-06,-1.18397543e-06,-1.18220896e-06,-1.17365528e-06,-1.16478111e-06,-1.15795535e-06,-1.15027524e-06,-1.14578597e-06,-1.13951899e-06,-1.13128294e-06,-1.12646285e-06,-1.11863255e-06,-1.11433667e-06,-1.10719509e-06,-1.10106384e-06,-1.08988513e-06,-1.08403424e-06,-1.07626136e-06,-1.06755999e-06,-1.05744425e-06,-1.05262563e-06,-1.04241917e-06,-1.03274499e-06,-1.02818206e-06,-1.01793512e-06,-1.01298201e-06,-1.01099988e-06,-1.00404429e-06,-9.96014592e-07,-9.86846771e-07,-9.75978082e-07,-9.71310101e-07,-9.65461595e-07,-9.57800921e-07,-9.50948163e-07,-9.44029466e-07,-9.35092658e-07, -9.2923824e-07,-9.22214099e-07,-9.12197208e-07,-9.06944933e-07,-9.02927013e-07,-8.94250945e-07,-8.82756183e-07,-8.77839625e-07,-8.69261726e-07,-8.59845784e-07,-8.51944776e-07, -8.4805697e-07,-8.45584168e-07,-8.33565764e-07,-8.30842509e-07,-8.11604764e-07,-8.05334594e-07,-7.98923679e-07,-7.95054177e-07,-7.81632764e-07,-7.79374602e-07,-7.74584691e-07,-7.69307235e-07,-7.62585614e-07,-7.55350129e-07,-7.46389901e-07,-7.40362339e-07,-7.36595553e-07,-7.33830916e-07,-7.28695341e-07,-7.15292799e-07,-7.01938632e-07,-6.99068778e-07,-6.97067208e-07,-6.90177444e-07,-6.82965378e-07, -6.7595164e-07,-6.68198425e-07,-6.58973704e-07,-6.55215501e-07, -6.5180285e-07,-6.43223132e-07,-6.34594358e-07,-6.33029913e-07,-6.21924187e-07,-6.12302813e-07,-6.01462716e-07,-5.95711413e-07,-5.92700644e-07,-5.89220292e-07,-5.79003824e-07,-5.73221598e-07, -5.6589505e-07,-5.57601084e-07,-5.53771883e-07,-5.49646586e-07,-5.43490955e-07,-5.24950394e-07,-5.22786763e-07,-5.13851205e-07,-5.04062996e-07,-4.95115899e-07,-4.89712193e-07,-4.86914359e-07,-4.80862411e-07,-4.74465367e-07,-4.72973966e-07,-4.63175923e-07, -4.5748348e-07,-4.50267407e-07,-4.45109947e-07,-4.34694186e-07,-4.21134928e-07, -4.1164725e-07,-4.07132802e-07,-3.98108085e-07,-3.85284039e-07,-3.85153584e-07,-3.76828382e-07,-3.64644166e-07,-3.63798591e-07,-3.61176347e-07, -3.4671416e-07,-3.43078483e-07,-3.26576583e-07,-3.23496636e-07,-3.21302736e-07,-3.14870704e-07,-3.06866866e-07,  -3.050136e-07, -2.9301367e-07,-2.85884454e-07, -2.7464057e-07,-2.66659271e-07,-2.66222173e-07,-2.54675172e-07,-2.50116472e-07,-2.47341404e-07,-2.41756368e-07,-2.38104604e-07,-2.27570411e-07,-2.17160391e-07,-2.09052814e-07,-2.07751981e-07, -2.0373372e-07,-1.91833706e-07,-1.82332101e-07,-1.77992291e-07,-1.73477929e-07,-1.70200181e-07, -1.6087759e-07,-1.51285491e-07,-1.48013982e-07,-1.42705716e-07,-1.38515134e-07,-1.25300232e-07,-1.20645723e-07,-1.09145176e-07,-1.04264231e-07,-9.84442607e-08,-9.71920144e-08,-9.09292481e-08,-7.99259396e-08,-7.19999775e-08,-6.64070114e-08,-6.16021438e-08,-5.10105096e-08,-4.56402702e-08,-3.42941036e-08,-3.13915152e-08,-2.39055993e-08,-1.31977345e-08,-8.33928393e-09,-5.48895374e-09,-1.83911011e-10, 1.79495636e-08, 2.03620409e-08, 2.55446508e-08,  3.4862957e-08, 3.71408788e-08, 4.69458179e-08, 4.83245444e-08,  5.3891327e-08, 6.78076617e-08, 7.14764212e-08, 7.70994291e-08, 8.00218203e-08, 9.39436475e-08, 1.06209754e-07, 1.10313479e-07, 1.18927993e-07, 1.23323105e-07, 1.29262233e-07, 1.34608186e-07, 1.46126723e-07, 1.49389436e-07, 1.59494505e-07, 1.65855525e-07, 1.70556305e-07, 1.81113677e-07, 1.92006866e-07, 1.97070307e-07, 2.08300293e-07, 2.11570025e-07, 2.21147687e-07, 2.34825492e-07, 2.35860611e-07, 2.43642603e-07, 2.45377208e-07, 2.57991104e-07, 2.71327934e-07, 2.76767651e-07, 2.82364766e-07, 2.91888824e-07, 2.93876582e-07, 3.02006612e-07, 3.07904884e-07, 3.16384558e-07, 3.28189969e-07, 3.30546754e-07, 3.38023682e-07, 3.39363453e-07, 3.49009753e-07, 3.58544696e-07, 3.62412663e-07, 3.66674158e-07, 3.72625721e-07, 3.76168856e-07, 3.80808217e-07,  3.9082164e-07, 3.98512952e-07, 3.99584508e-07,  4.1174809e-07, 4.19277029e-07, 4.25884565e-07, 4.29405333e-07, 4.39417704e-07, 4.44726936e-07, 4.52851197e-07, 4.54579038e-07, 4.63031256e-07, 4.75395268e-07, 4.80029939e-07, 4.88167814e-07, 4.91954779e-07,  5.0472056e-07, 5.06334459e-07, 5.14608644e-07, 5.21163997e-07, 5.26519443e-07,  5.3979079e-07, 5.43762269e-07, 5.52595338e-07, 5.58881993e-07, 5.62712557e-07, 5.71350824e-07,  5.8418982e-07, 5.87275736e-07, 5.98080248e-07, 6.01935881e-07, 6.09593769e-07, 6.17002399e-07, 6.21735296e-07, 6.28873238e-07, 6.32023614e-07, 6.36821937e-07,  6.5422546e-07,  6.5706314e-07, 6.63593028e-07, 6.67173651e-07, 6.80298854e-07,  6.8109847e-07,  6.9624474e-07, 6.99289899e-07, 7.04438548e-07, 7.11021016e-07, 7.17518844e-07, 7.24631263e-07, 7.37106689e-07, 7.40018891e-07, 7.44932947e-07, 7.64183596e-07, 7.69614473e-07, 7.74391651e-07, 7.82018844e-07, 7.89699698e-07, 7.93526056e-07, 8.02579507e-07,  8.1398332e-07, 8.23421601e-07, 8.27364943e-07, 8.31638204e-07, 8.50469064e-07, 8.52854782e-07, 8.55137159e-07, 8.60068155e-07, 8.65401319e-07, 8.74156285e-07, 8.85429415e-07, 8.89809655e-07, 8.95354276e-07, 9.15119472e-07, 9.17402645e-07, 9.26801931e-07, 9.30196677e-07, 9.44619728e-07, 9.51298148e-07, 9.56448844e-07, 9.60099442e-07, 9.69452003e-07, 9.74900786e-07, 9.82105576e-07,  9.8959697e-07, 9.94745051e-07, 1.00046736e-06, 1.00913212e-06, 1.01192506e-06, 1.01777448e-06, 1.02645583e-06, 1.03142406e-06, 1.04018852e-06, 1.04774938e-06, 1.06019456e-06, 1.06683592e-06, 1.07292567e-06, 1.07533663e-06, 1.08952804e-06, 1.09334349e-06, 1.09665802e-06, 1.10584165e-06, 1.11308896e-06, 1.12094619e-06, 1.13245108e-06,  1.1391279e-06, 1.16298406e-06,   1.164379e-06, 1.17015782e-06, 1.18185017e-06,  1.1910937e-06, 1.19520791e-06, 1.21345738e-06, 1.21460289e-06, 1.21682046e-06, 1.22867073e-06, 1.23122959e-06, 1.24128212e-06, 1.24765131e-06, 1.25461156e-06, 1.26701002e-06, 1.27460737e-06, 1.28099168e-06, 1.28499971e-06, 1.29005173e-06, 1.30895114e-06, 1.30990679e-06,   1.319852e-06, 1.32374328e-06, 1.33016351e-06, 1.34317156e-06, 1.34552818e-06, 1.35225673e-06, 1.35743585e-06, 1.36864128e-06,  1.3692229e-06, 1.37367829e-06, 1.38599125e-06, 1.39541601e-06, 1.40728696e-06, 1.41563442e-06, 1.41676583e-06, 1.43490297e-06, 1.44001785e-06, 1.45403487e-06, 1.45869558e-06, 1.46489276e-06, 1.47085575e-06, 1.47954813e-06,  1.4798735e-06, 1.49141226e-06,  1.4975692e-06, 1.51059612e-06, 1.51459176e-06, 1.52910013e-06, 1.53603764e-06, 1.54705413e-06, 1.55418843e-06, 1.56574765e-06, 1.56614988e-06, 1.57287468e-06, 1.57945965e-06, 1.59317869e-06, 1.59479123e-06, 1.59955971e-06, 1.60094794e-06, 1.60611773e-06, 1.61743753e-06, 1.62749257e-06, 1.62954177e-06, 1.63730704e-06, 1.65678284e-06, 1.66456516e-06, 1.67832968e-06, 1.68086194e-06, 1.69143811e-06, 1.70900478e-06, 1.71647002e-06, 1.72122702e-06,  1.7316529e-06, 1.73734406e-06, 1.74012553e-06,  1.7514094e-06, 1.75877028e-06, 1.76464198e-06, 1.77129334e-06, 1.78415371e-06, 1.78944799e-06, 1.79445749e-06, 1.79560629e-06, 1.81991595e-06, 1.82137865e-06, 1.82678446e-06, 1.85154749e-06, 1.85949216e-06, 1.86054967e-06, 1.86638408e-06, 1.87572323e-06, 1.87996682e-06, 1.89169259e-06, 1.89531659e-06, 1.90489777e-06,  1.9157801e-06, 1.92540574e-06, 1.93618598e-06, 1.94017889e-06, 1.95450457e-06, 1.95764801e-06, 1.97176064e-06, 1.98528278e-06, 1.99203805e-06, 2.01174248e-06,  2.0209427e-06, 2.02932461e-06,  2.0367595e-06, 2.04858816e-06,  2.0561165e-06, 2.06165328e-06, 2.07879839e-06, 2.08588835e-06, 2.09097698e-06, 2.10271855e-06, 2.11772021e-06, 2.12323607e-06, 2.12707505e-06, 2.13848989e-06, 2.14713441e-06, 2.15712771e-06, 2.16195758e-06, 2.16481521e-06, 2.16877083e-06, 2.17833895e-06,  2.1827118e-06, 2.18480318e-06,  2.2015804e-06, 2.21128721e-06, 2.22175663e-06, 2.23602183e-06, 2.23852976e-06, 2.26134557e-06, 2.26727957e-06, 2.27287455e-06, 2.28257363e-06,  2.2890556e-06,  2.3033183e-06, 2.31459535e-06, 2.32441903e-06, 2.32873549e-06, 2.34017193e-06, 2.35710331e-06, 2.35748644e-06,  2.3632906e-06, 2.37168024e-06, 2.38148573e-06, 2.38794223e-06, 2.39806786e-06, 2.40301915e-06, 2.41063026e-06, 2.42371311e-06,  2.4293613e-06, 2.43400336e-06,  2.4469357e-06,  2.4816286e-06, 2.48391689e-06, 2.49383334e-06, 2.49868003e-06, 2.51765891e-06,  2.5268987e-06, 2.53048438e-06, 2.54149063e-06, 2.54427005e-06, 2.56445537e-06, 2.57053784e-06,  2.5750528e-06, 2.58881687e-06, 2.59556987e-06, 2.60451429e-06, 2.62459389e-06, 2.63345828e-06, 2.63914785e-06, 2.66109964e-06, 2.66536517e-06, 2.67577525e-06, 2.68656777e-06, 2.69214956e-06, 2.70978649e-06, 2.71577869e-06, 2.72579996e-06, 2.74342483e-06, 2.74632748e-06, 2.75479943e-06,  2.7651065e-06, 2.76850938e-06, 2.77868116e-06, 2.78175003e-06, 2.79482242e-06, 2.79923461e-06, 2.82161204e-06,  2.8264576e-06, 2.84528119e-06, 2.86115255e-06, 2.86430532e-06, 2.87625403e-06, 2.88225738e-06, 2.88833689e-06, 2.90610524e-06, 2.91237257e-06, 2.92257073e-06, 2.94580195e-06, 2.94750635e-06, 2.95937184e-06, 2.97216275e-06, 2.97528709e-06, 2.98992813e-06, 3.00834017e-06,  3.0153542e-06, 3.02148715e-06, 3.03880142e-06, 3.05824415e-06, 3.06039647e-06, 3.07930441e-06, 3.08748076e-06, 3.09669076e-06, 3.10193809e-06, 3.10895712e-06, 3.12673569e-06, 3.13712735e-06,  3.1428026e-06,  3.1570205e-06,  3.1842942e-06, 3.19135506e-06, 3.19746414e-06, 3.21439893e-06, 3.22066171e-06, 3.23417498e-06, 3.24692678e-06, 3.25191559e-06, 3.27747148e-06, 3.28332862e-06, 3.30084731e-06, 3.30580588e-06, 3.30991952e-06, 3.34079368e-06,  3.3489423e-06, 3.36046696e-06, 3.37367715e-06, 3.38646009e-06,  3.4012337e-06, 3.41233817e-06, 3.43219358e-06, 3.44085356e-06, 3.45892568e-06, 3.46156003e-06, 3.47759146e-06, 3.49525862e-06, 3.50639493e-06, 3.52934808e-06, 3.53802079e-06, 3.55344173e-06, 3.55759721e-06, 3.58935313e-06, 3.59382329e-06, 3.61547836e-06, 3.62947799e-06, 3.63849563e-06, 3.64262678e-06, 3.65540814e-06, 3.67375742e-06, 3.68795827e-06, 3.70304997e-06, 3.73013177e-06, 3.73805415e-06,  3.7455286e-06, 3.74656383e-06, 3.76413936e-06, 3.78286495e-06, 3.80021538e-06, 3.81505288e-06, 3.83702672e-06, 3.85023259e-06, 3.86935199e-06, 3.87572891e-06, 3.89302068e-06, 3.90550213e-06, 3.90904734e-06, 3.93037408e-06, 3.94102972e-06, 3.95094094e-06, 3.95907591e-06, 4.00291719e-06, 4.01056377e-06, 4.01503439e-06, 4.04483944e-06,   4.049371e-06, 4.06751406e-06,  4.0816285e-06, 4.09471022e-06, 4.09665608e-06,  4.1159733e-06, 4.14582973e-06, 4.17253159e-06, 4.19249136e-06,  4.2110305e-06, 4.22975518e-06, 4.27127861e-06, 4.27409759e-06, 4.31038052e-06, 4.31462695e-06, 4.33401283e-06, 4.33628247e-06, 4.35380434e-06,  4.3602231e-06, 4.38466259e-06, 4.41902785e-06,  4.4540684e-06, 4.46966442e-06, 4.47691946e-06, 4.52545055e-06, 4.53495159e-06, 4.56714133e-06,  4.6010382e-06, 4.62372554e-06, 4.62905518e-06, 4.64434288e-06, 4.66934489e-06, 4.71265503e-06, 4.72984857e-06, 4.77136564e-06, 4.78605625e-06, 4.84095335e-06, 4.85332339e-06, 4.91406718e-06,  4.9897244e-06, 5.01883551e-06, 5.09357142e-06, 5.13577834e-06, 5.25094674e-06, 5.33422053e-06, 5.34618493e-06, 5.47557374e-06, 5.75201193e-06, 6.04954312e-06, 6.10825737e-06, 6.18314334e-06, 6.63335823e-06, 7.61935325e-06, 9.90379431e-06, 2.51701022e-05, 3.35904042e-05, 4.79517767e-05, 5.73783473e-05, 0.000117060328, 0.000158785333, 0.000173253997, 0.000228510791, 0.000312930235,    0.585785151,     0.58578527,    0.585786045,     0.58578819,    0.585788965,    0.585790992,    0.585793972,     0.58579433,    0.585796833,    0.585797906,    0.591592193,    0.892787099,    0.892789841,    0.892791271,    0.892794728,    0.892797828,    0.892798483,    0.892801523,    0.892802119,    0.901138902,    0.910619795,      0.9106341,    0.910637319,    0.910638094,    0.910638571,    0.910638809,    0.910638928,    0.910639286,    0.910639286,    0.910639524,    0.910639524,    0.910639763,    0.910639763,    0.910639882,    0.910639882,    0.910639882,     0.91064024,    0.910640359,    0.910640538,    0.910640597,    0.910640955,    0.910641253,    0.910641432,    0.910641551,    0.910641551,    0.910641611,     0.91064167,    0.910641968,    0.910641968,    0.910641968,    0.910642028,    0.910642147,    0.910642147,    0.910642147,    0.910642147,    0.910642266,    0.910642266,    0.910642266,    0.910642505,    0.910642505,    0.910642624,    0.910642684,    0.910642743,    0.910642743,    0.910642862,    0.910642982,    0.910643101,    0.910643339,    0.910643697,    0.910643697,    0.910643697,    0.910643697,    0.910644114,    0.910644174,    0.910644174,    0.910644293,    0.910644412,    0.910644412,    0.910644472,    0.910644531,     0.91064465,     0.91064477,     0.91064477,     0.91064477,    0.910645008,    0.910645247,    0.910645962,    0.910645962,    0.910645962,    0.910645962,    0.910646617,    0.910647154,    0.910647154,    0.910647154,    0.910647333,    0.910647631,     0.91064769,    0.910647869,    0.910648108,    0.910648346,    0.910649896,    0.910651565,    0.910655022,    0.910677195,    0.958105326,    0.958109856,    0.958112121,    0.958112359,    0.958112717,    0.958114207,    0.958114922,    0.958115995,    0.958117068,    0.958119035,    0.958120942,    0.958125949,    0.968101025,       1.263762,     1.59820068,     1.69440508,     1.69440889,     1.69440973,     1.69441187,     1.69441295,     1.69441295,     1.69441366,     1.69441962,     1.77684653,     1.94821191,     2.00000024,     2.00000358,     2.00000811,     2.00000834,     2.00001001,     2.00001001,     2.00001144,     2.00001335,     2.00001502,     2.00001574,     2.00001621,     2.00001621,     2.00001645,     2.00001764,     2.00001979,     2.00002098,     2.00002122,      2.0000217,     2.00002551,     2.15301728,     2.21416426,     2.21416759,     2.21417594,     2.21417665,     2.21418214,     2.21418333,     2.21418595,     2.21418667,     2.21418762,     2.21419168,     2.21419191,     2.21419716,      2.2754178,     2.27541924,     2.27542067,      2.2754209,      2.2754209,     2.27542186,      2.2754221,     2.27542257,     2.27542281,     2.27542329,     2.27542353,     2.27542353,       2.275424,     2.27542424,     2.27542448,     2.27542567,     2.27542567,     2.27542567,     2.27542567,     2.27542615,     2.27542663,     2.27542663,     2.27542686,     2.27542686,     2.27542734,     2.27542734,     2.27542758,     2.27542782,     2.27542782,     2.27542806,      2.2754283,     2.27542853,     2.27542853,     2.27542853,     2.27542877,     2.27542901,     2.27542925,     2.27542949,     2.27542973,     2.27542996,     2.27543068,     2.27543068,     2.27543092,     2.27543092,     2.27543116,     2.27543116,     2.27543163,     2.27543259,     2.27543354,     2.27543354,     2.27543354,     2.27543402,     2.27543402,     2.27543402,     2.27543473,     2.27543473,     2.27543497,     2.27543521,     2.27543545,     2.27543545,     2.27543592,     2.27543592,     2.27543616,     2.27543688,     2.27543855,      2.2754395,      2.2754395,     2.27543974,     2.27543998,     2.27544069,     2.27544069,     2.27544069,     2.27544165,     2.27544212,     2.27544332,     2.27544355,     2.27544451,     2.27544665,     2.27544713,     2.27544785,     2.27544904,     2.27545261,     2.27546167,     2.27546716,     2.33754373,      2.4384532,     2.43845677,     2.43845963,     2.43846083,     2.43846178,     2.43847203,     2.43848133,     2.45653248,     2.51680875,     2.56511068,     2.56511855,     2.56511879,      2.5651257,     2.56513286,     2.56513405,     2.56513619,     2.56513619,     2.56513858,     2.56514001,     2.56514144,     2.56514144,     2.65025544,     2.65025759,      2.6502614,     2.65027118,     2.65027142,     2.65027189,     2.65027905,     2.65028024,     2.65188885,     2.67112947,     2.67113209,     2.67113209,     2.67113256,      2.6711328,       2.671134,     2.67113423,     2.67113519,     2.67113566,     2.67113614,     2.67113638,     2.67113638,     2.67113709,     2.67113733,     2.67113733,     2.67113733,     2.67113781,     2.67113781,     2.67113781,     2.67113781,     2.67113781,     2.67113805,     2.67113829,     2.67113853,     2.67113876,     2.67113876,     2.67113924,     2.67113972,     2.67113972,     2.67114019,     2.67114043,     2.67114115,     2.67114139,     2.67114139,     2.67114162,     2.67114186,      2.6711421,     2.67114234,     2.67114234,     2.67114282,     2.67114305,     2.67114329,     2.67114353,     2.67114401,     2.67114425,     2.67114449,     2.67114449,     2.67114496,     2.67114496,     2.67114568,     2.67114568,     2.67114592,     2.67114592,     2.67114687,     2.67114758,     2.67114782,      2.6711483,     2.67114854,     2.67114878,     2.67114878,     2.67114878,     2.67114949,     2.67115021,     2.67115116,     2.67115164,     2.67115355,     2.67115355,     2.67115378,     2.67115426,      2.6711545,     2.67115498,     2.67115498,     2.67115641,     2.67115736,     2.67115831,     2.67116022,     2.67116046,     2.67116356,     2.67116618,     2.67116642,     2.67117167,     2.67117262,     2.67118812,      2.6712265,     2.97722816,     2.98423982,     3.00001192,     3.00001764,     3.00001907,     3.00001955,     3.00002289,      3.0000236,      3.0000267,     3.00002766,     3.00003004,     3.00003076,     3.00003099,     3.00003386,     3.00003576,     3.00004435,     3.41422319,     3.41423082,     3.41423106,     3.41423249,     3.41423845,      3.4142437,     3.41424608,     3.41424656,     3.41424847,     3.41425276,     3.42957616,      3.5342412,     3.53424358,     3.53424501,     3.53424549,     3.53424644,     3.53424668,     3.53424668,     3.53424692,      3.5342474,     3.53424811,     3.53424811,     3.53424978,     3.53425121,     3.53425169,     3.53425169,     3.53425217,     3.53425217,     3.53425217,     3.53425264,     3.53425312,      3.5342536,     3.53425384,     3.53425384,     3.53425407,     3.53425407,     3.53425455,     3.53425503,     3.53425503,      3.5342555,      3.5342555,      3.5342555,     3.53425646,     3.53425646,      3.5342567,      3.5342567,     3.53425741,     3.53425741,     3.53425789,     3.53425837,     3.53425837,     3.53425884,     3.53425884,     3.53425884,     3.53425932,     3.53425932,     3.53425956,      3.5342598,     3.53426027,     3.53426027,     3.53426075,      3.5342617,     3.53426218,     3.53426242,     3.53426313,     3.53426361,     3.53426385,     3.53426385,     3.53426528,     3.53426528,     3.53426528,     3.53426552,     3.53426647,     3.53426695,     3.53426743,     3.53426743,      3.5342679,     3.53426838,     3.53426933,     3.53426981,     3.53427076,     3.53427172,     3.53427219,     3.53427315,     3.53427362,     3.53427386,     3.53427458,     3.53427505,     3.53427839,     3.53428078,     3.53428388,     3.53428459,     3.53428602,     3.53430104,     3.53430128,     3.86746073,     3.91993761,     3.91994286,     3.91994333,     3.91994548,     3.91995001,     3.91995144,     3.91996622,     3.91997242,     3.93677235,      4.0000205,     4.00002384,     4.00002527,     4.00002575,     4.00002956,     4.00002956,     4.00003386,     4.00004578,     4.00005007,     4.39146471,     4.39147186,     4.39147615,     4.39147758,     4.39147806,     4.39147854,     4.39148092,     4.39148331,     4.39148426,     4.39148426,     4.39148521,     4.39148664,     4.39148808,     4.39148855,     4.39148951,     4.39148951,     4.39149046,     4.39149094,     4.39149094,     4.39149141,     4.39149141,     4.39149237,     4.39149332,      4.3914938,      4.3914938,      4.3914938,     4.39149427,     4.39149475,     4.39149475,     4.39149475,     4.39149618,     4.39149666,     4.39149666,     4.39149666,     4.39149761,     4.39149809,     4.39149809,     4.39149809,     4.39149809,     4.39149809,     4.39149857,     4.39149904,     4.39149952,         4.3915,     4.39150047,     4.39150047,     4.39150143,      4.3915019,     4.39150238,     4.39150238,     4.39150238,     4.39150286,     4.39150429,     4.39150429,     4.39150476,     4.39150524,     4.39150524,     4.39150572,      4.3915062,      4.3915062,     4.39150715,     4.39150763,     4.39150763,      4.3915081,      4.3915081,     4.39150858,     4.39150953,     4.39151001,     4.39151096,     4.39151144,     4.39151144,     4.39151192,     4.39151287,     4.39151382,     4.39151525,     4.39151669,     4.39151764,     4.39151955,     4.39152241,     4.39152336,     4.39153051,     4.39153242,     4.39153481,      4.3915453,     4.68032074,     4.69734764,      4.6973753,     4.69739199,     4.69739342,     4.69739628,     4.69741011,     4.69741535,      4.6974225,     4.75484467,     5.02033615,     5.03276968,     5.03278065,     5.03278875,     5.03278923,     5.03279734,     5.03280115,     5.03280354,      5.0328083,     5.03281021,     5.03281116,     5.03282356,     5.03282499,     5.95851851,     6.00009823,     6.00010586,     6.00011301,     6.00011444,     6.00012207,     6.00012875,     6.00013304,     6.00017071,     6.01386356,     6.01386738,     6.01388359,      6.0138855,     6.01388597,     6.01389122,     6.01389313,     6.01389599,     6.01389742,     6.01389742,      6.0138979,      6.0138998,     6.01390028,     6.01390028,     6.01390076,     6.01390076,     6.01390362,     6.01390362,     6.01390457,       6.013906,     6.01390648,     6.01390743,     6.01390743,     6.01390934,     6.01391029,     6.01391125,     6.01391125,     6.01391125,      6.0139122,      6.0139122,     6.01391315,     6.01391315,     6.01391411,     6.01391697,     6.01391792,     6.01391888,     6.01392031,     6.01392031,     6.01392078,     6.01392174,     6.01392174,     6.01392174,     6.01392269,     6.01392317,     6.01392317,     6.01392317,     6.01392317,      6.0139246,      6.0139246,     6.01392555,     6.01392603,     6.01392603,     6.01392651,     6.01392746,     6.01392841,     6.01392889,     6.01392937,     6.01393032,     6.01393127,     6.01393318,     6.01393318,     6.01393318,     6.01393509,     6.01393604,     6.01393747,     6.01393747,     6.01394033,     6.01394176,     6.01394272,     6.01394558,     6.01394606,     6.01395416,     6.01395464,     6.01395512,     6.01395702,     6.01396751,     6.01396894,     6.01396894,       6.013978,     6.01398039,     6.01398468,     6.01399803,     6.01402569,     6.01403809,     6.49848461,     6.56164074,     6.56164455,     6.56164598,     6.56165314,     6.56166935,     6.56168461,     6.56168747,     6.60118484,     6.74204493,     6.74204636,     6.74205112,     6.74205494,     6.74206448,     6.74208927,     6.74210548,     6.74210739,     6.74222279,     6.75201893,     6.75202274,     6.75202417,     6.75203037,     6.75203133,     6.75203133,     6.75203228,     6.75203276,     6.75203514,     6.75203705,       6.752038,       6.752038,       6.752038,       6.752038,     6.75203848,     6.75203896,     6.75203896,     6.75203991,     6.75204086,     6.75204134,     6.75204182,     6.75204277,     6.75204372,     6.75204563,     6.75204563,     6.75204706,     6.75204754,     6.75204945,     6.75205135,     6.75205326,     6.75205421,     6.75205517,     6.75205708,     6.75205851,     6.75205851,     6.75205898,     6.75205898,     6.75206089,     6.75206089,     6.75206089,     6.75206137,     6.75206184,      6.7520628,     6.75206375,     6.75206423,     6.75206423,     6.75206423,     6.75206423,     6.75206423,      6.7520647,     6.75206661,     6.75206757,     6.75206852,     6.75206995,     6.75207043,     6.75207138,     6.75207281,     6.75207281,     6.75207329,     6.75207329,      6.7520752,     6.75207615,     6.75207996,     6.75207996,     6.75208092,     6.75208282,     6.75208569,     6.75208664,     6.75208855,     6.75209045,     6.75209141,     6.75209427,     6.75209808,     6.75210476,     6.75211143,     6.75211573,     6.75212097,     6.75213432,     6.75214005,     6.75215578,     6.75216484,     6.75218391,     6.75220013,     6.75222588,     7.22997475,     7.22997761,     7.22998619,      7.2299881,     7.22998905,     7.22999954,     7.23000145,     7.23000526,     7.23000717,     7.23001385,     7.23002672,     7.23006535,      7.2685647,     9.00008202,     9.00010395,     9.00010967,     9.00013638,     9.00014687,     9.00021458,     9.00021935,     9.00770664,     9.40348911,     9.40352058,     9.40356445,     9.40356636,      9.4035778,     9.40358353,     9.40361595,     9.40368271,     9.40368462,     9.45131016,     9.45131111,     9.45131874,     9.45132065,     9.45132256,     9.45133209,       9.451334,       9.451334,     9.45133686,     9.45133781,     9.45133781,     9.45134354,      9.4513464,     9.45134735,     9.45134735,     9.45134735,     9.45135021,     9.45135021,     9.45135212,     9.45135212,     9.45135689,     9.45135689,     9.45135689,     9.45135784,     9.45135975,     9.45135975,      9.4513607,     9.45136166,     9.45136166,     9.45136261,     9.45136261,     9.45136356,     9.45136356,     9.45136452,     9.45136452,     9.45136929,     9.45137024,     9.45137024,     9.45137405,     9.45137405,     9.45137501,     9.45137501,     9.45137882,     9.45137882,     9.45137978,     9.45137978,     9.45137978,     9.45137978,     9.45138073,     9.45138073,     9.45138168,     9.45138168,     9.45138168,      9.4513855,      9.4513855,      9.4513855,     9.45138741,     9.45138741,     9.45138741,     9.45139217,     9.45139313,     9.45139313,     9.45139313,     9.45139503,     9.45139694,      9.4513979,     9.45139885,     9.45140266,     9.45140266,     9.45140362,     9.45140934,     9.45141125,     9.45141411,     9.45142651,      9.4514389,     9.45144176,     9.45144367,     9.45145035,     9.45146275,     9.45146561,     9.45147133,     9.45148182,     9.45153999,     9.45156956,     87.9626617,     175.048248,     333.664551,     338.411163,     345.676697,     351.015503,     357.930511]
eigs2 = [-0.000100783211,-4.14679089e-05,-2.44666335e-05,-1.77486763e-05,-6.55014992e-06,-4.95292625e-06,-4.25025382e-06, -4.1293074e-06,-3.85537396e-06,-3.50893743e-06,-3.48816889e-06,-3.30708258e-06,-3.22767983e-06,-3.10098812e-06,-3.03735169e-06,-3.00904685e-06,-2.98537043e-06,-2.94014967e-06,-2.91927904e-06,-2.78669995e-06,-2.76743413e-06,-2.76233027e-06,-2.72738521e-06,-2.72347711e-06,-2.64037931e-06,-2.60117258e-06,-2.57927059e-06,-2.57476768e-06,-2.44756689e-06,-2.41647172e-06,-2.37932818e-06,-2.36946698e-06,-2.32946854e-06, -2.2780705e-06,-2.25253257e-06,-2.23159691e-06,-2.16993703e-06,-2.16616536e-06,-2.12309237e-06,-2.10064832e-06,-2.05793503e-06, -2.0429602e-06,-1.97282566e-06,-1.96603128e-06,-1.95435064e-06,-1.90187234e-06,-1.80103052e-06,-1.76774233e-06,-1.75761693e-06, -1.7570635e-06,-1.74223635e-06,-1.71819454e-06, -1.6756303e-06,-1.67022142e-06, -1.6247069e-06,-1.62319213e-06,-1.60087188e-06,-1.57313616e-06, -1.5521972e-06,-1.46482114e-06,-1.42172109e-06,-1.38031555e-06,-1.36357403e-06,-1.35406947e-06,-1.33404149e-06,-1.31674449e-06,-1.29323041e-06,-1.25916711e-06,-1.23998916e-06,-1.23718735e-06,-1.20438813e-06,-1.14198906e-06,-1.13128306e-06,-1.11534166e-06,-1.07418361e-06,-1.07167546e-06,-1.02684805e-06,-1.00243562e-06, -9.9285478e-07,-9.62083504e-07,-9.24957078e-07,-8.89857859e-07,-8.77122034e-07,-8.68413565e-07,-8.68072902e-07,-8.19695799e-07,-8.12934957e-07,-7.94268658e-07,-7.75041315e-07,-7.61363992e-07,-7.16868556e-07,-7.16434101e-07,-7.15520457e-07,-6.95265328e-07,-6.79981724e-07,-6.60805313e-07,-6.48506557e-07,-6.16591365e-07,-5.99635598e-07,-5.51578808e-07, -5.4143004e-07,-5.15219654e-07,-5.06929837e-07, -4.7864313e-07,-4.42717976e-07,-4.41970684e-07,-4.22945732e-07,-4.17823514e-07,-4.14149412e-07,-4.02351475e-07,-3.74003406e-07,  -3.696085e-07,-3.55381502e-07, -3.3039322e-07,-3.21919941e-07,-3.03409422e-07,-2.98955229e-07,-2.93584833e-07,-2.71939143e-07, -2.6546698e-07, -2.3381395e-07,-2.15691585e-07,-2.06180871e-07,-1.87793134e-07,-1.84913418e-07,-1.61260829e-07,-1.57740445e-07,-1.51266107e-07,-1.30084473e-07,-1.16169531e-07,-9.66971712e-08,-8.64786216e-08,-8.26938731e-08, -7.9087016e-08, -5.2026131e-08,-4.30005187e-08,-3.32760735e-08,-2.47358045e-08,-1.63135798e-08,-3.55908591e-09,-3.85048438e-14,-2.81848265e-14,-2.63806158e-14,-2.37880411e-14,-1.54860374e-14,-1.24675643e-14,-1.13391547e-14,-9.12106762e-15,-8.76504866e-15,-8.50981984e-15,-8.23910811e-15,-5.90194389e-15,-4.97212279e-15,-4.92239899e-15,-4.90856694e-15,-4.24207695e-15,-3.91833757e-15,-3.90200762e-15,-3.41329481e-15,-2.86857448e-15,-2.00744246e-15,-1.54453906e-15,-1.47240383e-15,-6.96851147e-16,-5.49413628e-16,-2.42271434e-16,-1.33758242e-16,-1.20772022e-16,-1.24906857e-21,-1.24220556e-21, -1.0205874e-21,-8.13267176e-22,-7.15755184e-22,-5.31597637e-22,-4.13983626e-22,-2.78702715e-22,-3.98912697e-23,              0,              0,              0,              0,              0,              0, 2.84529128e-23, 4.83270579e-23, 6.20530862e-22, 6.74398374e-22,  7.8567214e-22, 8.00684984e-22, 8.09263751e-22, 1.58042348e-21, 4.93852713e-16, 7.96457298e-16, 1.22835352e-15, 2.09006608e-15,  3.9077522e-15,  3.9583802e-15, 4.04613832e-15, 4.24167969e-15, 4.29069833e-15, 4.68755656e-15, 7.52980696e-15, 9.15721221e-15,  1.0793037e-14,  1.0821122e-14, 1.24932413e-14, 1.43303914e-14, 1.66820886e-14, 2.06753255e-14, 2.25817628e-14,  2.7648448e-14, 3.22216381e-14, 7.01896374e-10, 7.95591149e-09, 1.03351949e-08, 1.85075191e-08, 2.31403341e-08, 3.53343665e-08, 4.16098658e-08, 6.21589109e-08, 6.50201741e-08, 7.50656355e-08, 8.90462744e-08, 1.02472271e-07, 1.21886501e-07, 1.37912949e-07, 1.49399185e-07, 1.85927064e-07, 1.90851495e-07, 2.05082358e-07, 2.22758487e-07, 2.29923373e-07,  2.3141817e-07, 2.51879669e-07, 2.55557893e-07, 2.62733209e-07, 2.84429547e-07, 2.91112485e-07, 3.20712047e-07, 3.24548694e-07, 3.50667705e-07, 3.54488122e-07, 3.64246773e-07, 3.84471207e-07, 4.02362076e-07, 4.20982047e-07, 4.54276886e-07, 4.72907743e-07, 4.80608094e-07, 4.97238773e-07, 5.09199822e-07, 5.26656265e-07, 5.55645784e-07, 5.83070118e-07, 6.01220052e-07, 6.18600609e-07, 6.42984503e-07, 6.63117135e-07,  6.6511609e-07, 6.71464306e-07, 7.00868156e-07, 7.30447027e-07, 7.31354419e-07, 7.56784004e-07, 7.80665516e-07, 8.01713156e-07, 8.16928321e-07, 8.20430671e-07, 8.43833391e-07, 8.67463029e-07, 8.68774066e-07,  9.0099303e-07, 9.37255095e-07,  9.4993004e-07, 9.64738433e-07, 9.87929297e-07, 9.88268539e-07, 1.05758431e-06, 1.07369897e-06, 1.12418945e-06, 1.12525072e-06, 1.17220259e-06, 1.19939818e-06, 1.21561618e-06, 1.22367555e-06, 1.26683051e-06, 1.28289014e-06, 1.30589808e-06, 1.31981631e-06, 1.35145069e-06, 1.37267307e-06, 1.38077496e-06, 1.41236467e-06, 1.42920112e-06, 1.45106617e-06, 1.45864146e-06, 1.48676349e-06, 1.50212702e-06, 1.52362554e-06, 1.58754426e-06, 1.59889214e-06, 1.63941854e-06, 1.64917435e-06, 1.66481345e-06, 1.68467113e-06, 1.68474571e-06, 1.75603384e-06, 1.76215246e-06, 1.79957408e-06, 1.82044676e-06, 1.85776344e-06, 1.92113703e-06,  1.9619697e-06, 1.97715167e-06, 1.98279076e-06, 1.98499561e-06, 2.05915671e-06, 2.08977099e-06, 2.12428836e-06, 2.15214436e-06, 2.17899264e-06, 2.17930733e-06, 2.26345969e-06, 2.29579996e-06, 2.29999932e-06, 2.34311824e-06, 2.36179358e-06, 2.36584356e-06, 2.45354749e-06, 2.47077992e-06, 2.55425789e-06, 2.56837234e-06, 2.58575415e-06, 2.64663026e-06, 2.67620499e-06, 2.68309122e-06, 2.68704139e-06, 2.71398358e-06, 2.71875774e-06, 2.77541676e-06, 2.90838329e-06, 2.93129096e-06, 2.95731388e-06, 2.98642772e-06, 3.00940815e-06, 3.09252528e-06, 3.28261603e-06, 4.53587472e-06, 5.04140098e-06, 8.86070939e-06, 1.50812266e-05, 2.39134406e-05, 3.80938764e-05, 7.77015739e-05,    0.585785687,    0.585785747,    0.585786998,    0.585787117,    0.585787594,    0.585787714,    0.585788548,    0.585789621,      0.5857898,     0.58579123,    0.591583014,    0.892786622,    0.892788708,    0.892789364,    0.892789781,    0.892791152,    0.892791331,    0.892792881,    0.892795265,     0.90113622,    0.910629869,    0.910635293,    0.910635293,    0.910636187,    0.910637021,    0.910637021,    0.910637617,    0.910637677,    0.910637915,    0.910638034,    0.910638154,    0.910638154,    0.910638273,    0.910638273,    0.910638332,    0.910638332,    0.910638452,    0.910638511,    0.910638869,    0.910638988,    0.910639107,    0.910639346,    0.910639346,    0.910639405,    0.910639584,    0.910639644,    0.910639822,    0.910639942,    0.910640001,     0.91064018,     0.91064024,    0.910640299,    0.910640299,    0.910640419,    0.910640478,    0.910640597,    0.910640836,    0.910640836,    0.910640895,    0.910640895,    0.910640955,    0.910640955,    0.910641134,    0.910641253,    0.910641253,    0.910641313,    0.910641372,    0.910641551,    0.910641551,     0.91064167,     0.91064173,     0.91064173,    0.910641789,    0.910641789,    0.910641789,    0.910641909,    0.910641968,    0.910642326,    0.910642564,    0.910642803,    0.910642862,    0.910642982,    0.910643399,    0.910643399,    0.910643458,    0.910643458,    0.910643637,    0.910643697,    0.910643816,    0.910644114,    0.910644114,    0.910644114,    0.910644352,    0.910644472,    0.910644531,    0.910644591,    0.910644948,    0.910645425,    0.910645604,      0.9106462,    0.910646677,    0.910646915,    0.910647929,    0.910656869,    0.958104789,    0.958107173,    0.958108366,    0.958109379,    0.958112359,    0.958114028,    0.958114624,     0.95811677,    0.958117068,    0.958117962,    0.958118796,    0.958120108,    0.968094349,     1.26375973,     1.59820509,     1.69440877,     1.69440925,     1.69441199,     1.69441414,     1.69441569,      1.6944176,     1.69441795,     1.69441843,     1.77682364,     1.94820249,     2.00000024,     2.00000238,     2.00000381,     2.00000858,     2.00000882,     2.00000954,     2.00001097,     2.00001144,     2.00001144,     2.00001144,     2.00001264,     2.00001311,     2.00001311,     2.00001311,     2.00001478,     2.00001574,     2.00001645,      2.0000186,     2.00001931,      2.1530273,     2.21416998,     2.21417236,     2.21417332,     2.21417379,     2.21417427,     2.21417427,     2.21417642,     2.21417832,     2.21417856,     2.21417975,     2.21418071,     2.21418858,     2.27540278,     2.27541924,     2.27541924,     2.27541971,     2.27541995,     2.27542043,      2.2754209,     2.27542162,     2.27542162,     2.27542186,     2.27542233,     2.27542233,     2.27542305,     2.27542329,     2.27542329,     2.27542329,     2.27542448,     2.27542472,     2.27542472,     2.27542472,     2.27542472,     2.27542496,      2.2754252,      2.2754252,     2.27542567,     2.27542567,     2.27542567,     2.27542591,     2.27542591,     2.27542639,     2.27542686,     2.27542686,     2.27542686,     2.27542686,      2.2754271,     2.27542734,     2.27542734,     2.27542806,     2.27542806,     2.27542806,     2.27542853,     2.27542853,     2.27542877,     2.27542901,     2.27542901,     2.27542901,     2.27542901,     2.27542925,     2.27542925,     2.27542949,     2.27542973,      2.2754302,      2.2754302,      2.2754302,      2.2754302,     2.27543116,     2.27543139,     2.27543187,     2.27543235,     2.27543235,     2.27543449,     2.27543449,     2.27543449,     2.27543449,     2.27543497,     2.27543521,     2.27543616,     2.27543712,     2.27543712,     2.27543736,     2.27543736,     2.27543783,     2.27543855,     2.27543855,     2.27543926,     2.27544141,     2.27544188,     2.27544188,      2.2754426,     2.27544308,     2.27544498,     2.27544832,     2.27544975,     2.27545309,     2.33753824,     2.43845129,     2.43845391,     2.43845534,      2.4384613,      2.4384613,     2.43846321,     2.43846655,     2.45651174,     2.51680756,     2.56511235,     2.56511259,     2.56511688,     2.56511807,     2.56511974,      2.5651226,     2.56512308,      2.5651238,     2.56512403,      2.5651257,     2.56512618,     2.56512713,     2.65025401,     2.65025473,     2.65025496,     2.65025759,      2.6502583,     2.65026188,     2.65026236,     2.65026593,     2.65187502,     2.67111158,     2.67112637,      2.6711297,     2.67112994,     2.67113137,     2.67113233,     2.67113233,     2.67113256,      2.6711328,     2.67113352,     2.67113376,     2.67113376,       2.671134,     2.67113423,     2.67113423,     2.67113447,     2.67113447,     2.67113519,     2.67113519,     2.67113543,     2.67113566,     2.67113662,     2.67113686,     2.67113686,     2.67113709,     2.67113733,     2.67113757,     2.67113853,     2.67113853,     2.67113853,     2.67113876,     2.67113924,     2.67113972,     2.67113972,     2.67113996,     2.67114019,     2.67114019,     2.67114091,     2.67114091,     2.67114115,     2.67114162,     2.67114162,     2.67114186,     2.67114258,     2.67114258,     2.67114258,     2.67114282,     2.67114305,     2.67114305,     2.67114329,     2.67114353,     2.67114377,     2.67114377,     2.67114377,     2.67114401,     2.67114425,     2.67114425,     2.67114472,     2.67114496,     2.67114496,      2.6711452,     2.67114568,     2.67114663,     2.67114711,     2.67114735,     2.67114758,     2.67114782,     2.67114782,     2.67114806,     2.67114806,     2.67115164,     2.67115259,     2.67115307,      2.6711545,     2.67115474,     2.67115569,     2.67115617,     2.67115641,     2.67115688,     2.67115784,     2.67116141,     2.67116284,     2.67116475,     2.67116809,     2.97724819,     2.98425436,     2.99999714,     3.00000167,     3.00000834,     3.00000954,     3.00001121,     3.00001311,     3.00001454,     3.00001478,     3.00001645,     3.00001645,     3.00001717,     3.00002122,     3.00002909,     3.00002956,     3.41422033,     3.41422653,     3.41422749,     3.41422772,     3.41422915,     3.41422987,     3.41423512,     3.41423678,     3.41424203,      3.4142499,     3.42956853,     3.53423738,     3.53424096,      3.5342412,     3.53424287,     3.53424287,     3.53424358,     3.53424478,     3.53424525,     3.53424597,     3.53424597,     3.53424644,     3.53424644,     3.53424644,     3.53424692,     3.53424692,     3.53424716,     3.53424764,     3.53424788,     3.53424907,     3.53424907,     3.53424954,     3.53424978,     3.53424978,     3.53425026,     3.53425026,     3.53425074,     3.53425121,     3.53425121,     3.53425121,     3.53425121,     3.53425145,     3.53425169,     3.53425241,     3.53425288,     3.53425336,     3.53425336,     3.53425384,     3.53425503,      3.5342555,     3.53425574,     3.53425574,     3.53425598,     3.53425646,     3.53425646,      3.5342567,      3.5342567,     3.53425717,     3.53425717,     3.53425741,     3.53425741,     3.53425741,     3.53425765,     3.53425765,     3.53425813,     3.53425813,     3.53425837,     3.53425884,     3.53425908,     3.53425908,     3.53425932,      3.5342598,      3.5342598,     3.53426003,      3.5342617,      3.5342617,     3.53426194,     3.53426361,     3.53426361,     3.53426409,     3.53426433,     3.53426456,     3.53426528,     3.53426528,     3.53426528,     3.53426528,       3.534266,       3.534266,     3.53426695,     3.53426862,     3.53426933,     3.53427005,     3.53427315,     3.53427482,     3.53427792,     3.86741352,     3.91992831,     3.91993284,     3.91993809,     3.91993856,     3.91994047,      3.9199419,     3.91994452,     3.91995001,     3.93674898,     4.00001335,     4.00001431,     4.00001669,     4.00001955,     4.00002098,     4.00002241,     4.00002575,     4.00003672,     4.00004482,     4.39146614,     4.39146662,     4.39146805,     4.39147091,     4.39147091,     4.39147186,     4.39147186,     4.39147282,     4.39147282,     4.39147329,     4.39147329,     4.39147329,     4.39147329,     4.39147425,     4.39147568,     4.39147663,     4.39147758,     4.39147806,     4.39147806,     4.39147854,     4.39147854,     4.39147854,     4.39147854,     4.39147854,     4.39147854,     4.39147949,     4.39147949,     4.39147997,     4.39148045,     4.39148045,     4.39148045,     4.39148092,     4.39148188,     4.39148188,     4.39148188,     4.39148235,     4.39148283,     4.39148331,     4.39148378,     4.39148426,     4.39148426,     4.39148474,     4.39148569,     4.39148617,     4.39148664,     4.39148664,     4.39148664,     4.39148664,     4.39148712,      4.3914876,      4.3914876,      4.3914876,     4.39148808,     4.39148808,     4.39148808,     4.39148855,     4.39148903,     4.39148903,     4.39148903,     4.39148951,     4.39149046,     4.39149046,     4.39149046,     4.39149094,     4.39149094,     4.39149141,     4.39149141,     4.39149237,     4.39149237,     4.39149237,     4.39149332,      4.3914938,      4.3914938,     4.39149475,     4.39149523,      4.3914957,     4.39149666,     4.39149761,     4.39149809,         4.3915,     4.39150286,     4.39150286,     4.39150524,     4.39151335,     4.68025446,     4.69732618,     4.69732857,        4.69733,     4.69733095,     4.69734001,     4.69734478,     4.69737244,     4.69740248,     4.75476933,     5.02025557,     5.03273058,     5.03273344,     5.03273821,     5.03273821,     5.03274059,     5.03274155,     5.03274441,     5.03275108,     5.03275394,     5.03276157,     5.03276253,     5.03277969,     5.95850468,      6.0000186,     6.00002003,     6.00002241,     6.00002289,     6.00002813,     6.00002956,      6.0000453,     6.00007772,     6.01386261,     6.01386356,     6.01387072,     6.01387119,      6.0138731,     6.01387405,     6.01387453,     6.01387596,     6.01387644,     6.01387739,     6.01387787,     6.01387787,     6.01387978,     6.01388073,     6.01388073,     6.01388073,     6.01388073,     6.01388311,     6.01388311,     6.01388311,     6.01388407,     6.01388407,     6.01388407,     6.01388597,     6.01388597,     6.01388597,     6.01388645,     6.01388788,     6.01388979,     6.01388979,     6.01388979,     6.01388979,     6.01388979,     6.01389027,     6.01389027,     6.01389122,     6.01389217,     6.01389313,      6.0138936,     6.01389456,     6.01389647,      6.0138979,      6.0138979,      6.0138979,     6.01389885,     6.01389885,      6.0138998,     6.01390028,     6.01390076,     6.01390076,     6.01390219,     6.01390219,     6.01390219,     6.01390314,     6.01390314,     6.01390362,     6.01390362,     6.01390409,     6.01390409,     6.01390505,     6.01390505,     6.01390505,     6.01390553,     6.01390553,     6.01390553,     6.01390648,     6.01390839,     6.01391077,     6.01391077,     6.01391172,     6.01391172,     6.01391268,     6.01391268,     6.01391268,     6.01391506,     6.01391554,     6.01391935,     6.01392078,     6.01392078,     6.01392126,      6.0139246,     6.01392984,      6.0139308,     6.01397371,      6.4984107,     6.56155014,     6.56156111,     6.56159019,     6.56159496,     6.56160069,     6.56162786,     6.56163359,     6.60112524,     6.74194336,     6.74195147,      6.7419529,     6.74195671,     6.74196911,     6.74197054,     6.74197721,     6.74198627,     6.74216366,     6.75199652,     6.75199842,     6.75200415,     6.75200558,     6.75200891,     6.75201464,     6.75201559,     6.75201607,      6.7520175,     6.75201797,     6.75201893,     6.75201941,     6.75202084,     6.75202084,     6.75202131,     6.75202227,     6.75202227,     6.75202227,     6.75202274,     6.75202274,     6.75202274,     6.75202322,     6.75202608,     6.75202608,     6.75202656,     6.75202656,     6.75202751,     6.75202751,     6.75202847,     6.75202942,      6.7520299,     6.75203085,     6.75203085,     6.75203085,     6.75203133,     6.75203276,     6.75203276,     6.75203276,     6.75203371,     6.75203466,     6.75203657,     6.75203705,       6.752038,     6.75204134,     6.75204134,     6.75204182,     6.75204229,     6.75204325,     6.75204325,     6.75204515,     6.75204563,     6.75204563,     6.75204659,     6.75204706,     6.75204706,     6.75204706,     6.75204802,     6.75204802,     6.75204849,     6.75204897,      6.7520504,      6.7520504,      6.7520504,     6.75205088,     6.75205088,     6.75205231,     6.75205517,     6.75205612,     6.75205612,     6.75205612,     6.75205755,     6.75205898,     6.75206041,     6.75206089,     6.75206089,      6.7520628,     6.75206614,     6.75206757,     6.75207043,     6.75207138,     6.75207233,     6.75207758,     6.75209665,     6.75211239,     7.22990847,     7.22993565,     7.22993994,     7.22994423,     7.22994709,     7.22995043,     7.22995329,     7.22995329,     7.22997379,     7.22997713,     7.22998238,     7.22999001,     7.26847553,     9.00004005,     9.00005341,     9.00007439,     9.00008106,     9.00009537,     9.00011635,     9.00012875,     9.00757504,     9.40344524,     9.40345192,     9.40345192,     9.40346336,     9.40346527,     9.40347385,     9.40349197,     9.40351963,     9.40356064,     9.45127773,     9.45128536,     9.45128632,     9.45129871,     9.45129967,     9.45129967,     9.45130348,     9.45130348,     9.45130634,     9.45130634,     9.45130634,      9.4513073,      9.4513073,     9.45131016,     9.45131016,     9.45131016,     9.45131207,     9.45131207,     9.45131207,     9.45131302,     9.45131493,     9.45131588,     9.45131683,     9.45131683,     9.45131874,     9.45131874,     9.45131874,     9.45131874,     9.45131969,     9.45132065,     9.45132065,     9.45132351,     9.45132351,     9.45132446,     9.45132542,     9.45132542,     9.45132732,     9.45132732,     9.45132923,     9.45133209,     9.45133209,       9.451334,       9.451334,     9.45133495,     9.45133495,     9.45133495,     9.45133591,     9.45133591,     9.45133591,     9.45133591,     9.45133686,     9.45133877,     9.45134163,     9.45134258,     9.45134258,     9.45134449,     9.45134449,     9.45134544,     9.45134544,     9.45134544,      9.4513464,      9.4513464,     9.45134735,     9.45134735,     9.45134735,      9.4513483,      9.4513483,     9.45135117,     9.45135117,     9.45135307,     9.45135498,     9.45135689,      9.4513588,     9.45135975,     9.45136166,     9.45136166,     9.45136261,     9.45136356,     9.45137215,     9.45137691,     9.45137978,     9.45139599,     9.45141506,     9.45142841,     87.9626923,     175.048233,     333.664368,     338.410797,     345.676727,     351.015198,     357.930389]

# %%
import numpy as np

# %%
eigs1 = [x if x > 1e-3 else 0 for x in eigs1]
eigs2 = [x if x > 1e-3 else 0 for x in eigs2]

eigs01 = [x for x in eigs1 if x == 0]
eigs02 = [x for x in eigs2 if x == 0]
eigs1nz = [x for x in eigs1 if x > 0]
eigs2nz = [x for x in eigs2 if x > 0]

# %%
print(eigs1nz)
print(eigs2nz)
print("num zeros eigs1:",len(eigs01))
print("num zeros eigs2:",len(eigs02))
print(len(eigs1nz),len(eigs2nz))

diff = np.array(eigs1nz) - np.array(eigs2nz)
diff.max()
# Out:
# [0.585785151, 0.58578527, 0.585786045, 0.58578819, 0.585788965, 0.585790992, 0.585793972, 0.58579433, 0.585796833, 0.585797906, 0.591592193, 0.892787099, 0.892789841, 0.892791271, 0.892794728, 0.892797828, 0.892798483, 0.892801523, 0.892802119, 0.901138902, 0.910619795, 0.9106341, 0.910637319, 0.910638094, 0.910638571, 0.910638809, 0.910638928, 0.910639286, 0.910639286, 0.910639524, 0.910639524, 0.910639763, 0.910639763, 0.910639882, 0.910639882, 0.910639882, 0.91064024, 0.910640359, 0.910640538, 0.910640597, 0.910640955, 0.910641253, 0.910641432, 0.910641551, 0.910641551, 0.910641611, 0.91064167, 0.910641968, 0.910641968, 0.910641968, 0.910642028, 0.910642147, 0.910642147, 0.910642147, 0.910642147, 0.910642266, 0.910642266, 0.910642266, 0.910642505, 0.910642505, 0.910642624, 0.910642684, 0.910642743, 0.910642743, 0.910642862, 0.910642982, 0.910643101, 0.910643339, 0.910643697, 0.910643697, 0.910643697, 0.910643697, 0.910644114, 0.910644174, 0.910644174, 0.910644293, 0.910644412, 0.9
# ...

# %%
import flowmodnum

# %%
from flowmodnum import water_levels

# %% [markdown]
# ## Prueba de funciones en water levels

# %%
water_levels.plot_hydrograms('inputs/pozos/niveles_observados.dat', 'model_dir', 'inputs/pozos/coord_pozos.dat', 
                             3, '01/01/2015', format_date='%d/%m/%Y', lang='EN')

# %%
water_levels.plot_fit('inputs/pozos/niveles_observados.dat', 'model_dir', 'inputs/pozos/coord_pozos.dat', 
                      '01/01/2015', format_date='%d/%m/%Y', lang='EN')

# %%
water_levels.get_stats('inputs/pozos/niveles_observados.dat', 'model_dir', 'inputs/pozos/coord_pozos.dat', 
                       '01/01/2015', format_date='%d/%m/%Y', lang='EN')

# %%
water_levels.mapped_hydrograms('inputs/pozos/niveles_observados.dat', 'model_dir', 24879, 'inputs/pozos/coord_pozos.dat', 
                               '01/01/2015', format_date='%d/%m/%Y', lang='EN', grid_dir='inputs/grid.shp')
# Out:
# 100%|██████████| 291/291 [00:02<00:00, 102.24it/s]

# %%
water_levels.generate_contours('model_dir', '01/01/2015', [1,4], [113], 24879, [2290, 2291, 2292, 2293], dry_cells = -999.99)

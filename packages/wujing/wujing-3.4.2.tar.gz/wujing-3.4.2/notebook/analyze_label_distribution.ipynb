# %%
import json
from datasets import load_dataset
from wujing.utils.split import analyze_label_distribution

data = load_dataset(
    "json", data_files="./../../testdata/standardized_credit_card.jsonl", split="train"
)
print(
    json.dumps(
        analyze_label_distribution(dataset=data, label_column="label_from_rpa"),
        indent=4,
        ensure_ascii=False,
    )
)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# {
#     "distribution": {
#         "无响应": {
#             "count": 1263681,
#             "percentage": "67.9%",
#             "samples_count": 1263681
#         },
#         "通用否定": {
#             "count": 170191,
#             "percentage": "9.1%",
#             "samples_count": 170191
#         },
#         "语音信箱": {
#             "count": 119885,
#             "percentage": "6.4%",
#             "samples_count": 119885
#         },
#         "通用肯定": {
#             "count": 98631,
#             "percentage": "5.3%",
#             "samples_count": 98631
#         },
#         "未识别": {
#             "count": 82011,
#             "percentage": "4.4%",
#             "samples_count": 82011
#         },
#         "没听清": {
#             "count": 26532,
#             "percentage": "1.4%",
#             "samples_count": 26532
#         },
#         "公司名称": {
#             "count": 16309,
#             "percentage": "0.9%",
# ...
